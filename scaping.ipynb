# %%
import pandas as pd

# %%
# URL du site web
url = "https://www.saskatchewan.ca/business/agriculture-natural-resources-and-industry/agribusiness-farmers-and-ranchers/market-and-trade-statistics/crops-statistics/crop-report"


tables = pd.read_html(url,header=1)

# Nous voulons extraire les tableaux qui ont pour indice 2,3
table1 = tables[2]
table2 = tables[3]

# %%
# supprimer Unamed au niveau des colonne
for col in table1.columns:
    
    if "Unnamed" in col:
        
        table1 = table1.rename(columns={col: "Commodity"})

table1
# Out:
#                                     Per cent combined  \
# 0                                       Winter wheat*
# 1                                          Fall rye**
# 2                                        Spring wheat
# 3                                               Durum
# 4                                             Oats***
# 5                                          Barley****
# 6                                          Canaryseed
# 7                                                Flax
# 8                                              Canola
# 9                                             Mustard
# 10                                           Soybeans
# 11                                         Lentils***
# 12                                            Peas***
# 13                                          Chickpeas
# 14  *includes three per cent ‘other’  **includes e...
#
#                                   Per cent combined.1
# 0                                                  56
# 1                                                  61
# 2                                                   2
# 3                                                   7
# 4                                                   3
# 5                                                  12
# 6                                                   5
# 7                                                   0
# 8                                                   1
# 9                                                   9
# 10                                                  0
# 11                                                 36
# 12                                                 36
# 13                                                  5
# 14  *includes three per cent ‘other’  **includes e...

# %%
for col in table2.columns:
    if "Unnamed" in col:
        table2 = table2.rename(columns={col: "Condition"})
table2
# Out:
#                   All Crops  All Crops.1
# 0                Aug. 14/23            9
# 1                Aug. 15/22            4
# 2                Aug. 16/21           18
# 3                Aug. 17/20            4
# 4                Aug. 19/19            1
# 5                Aug. 13/18           13
# 6   5 year avg. (2018-2022)            8
# 7  10 year avg. (2013-2022)            5
